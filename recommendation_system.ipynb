# %% [markdown]
# # Recommendation System

# %%
import pandas as pd
import re
import json

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Load Dataset

# %% [markdown]
# ## metadata

# %%
file_path_meta = 'data/meta_Appliances.jsonl'
data = []

# %%
with open(file_path_meta, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            data.append(json.loads(line))
        except json.JSONDecodeError:
            continue

df_meta = pd.DataFrame(data)
df_meta.head(5)
# Out:
#               main_category  \
# 0   Industrial & Scientific
# 1  Tools & Home Improvement
# 2  Tools & Home Improvement
# 3  Tools & Home Improvement
# 4  Tools & Home Improvement
#
#                                                title  average_rating  \
# 0  ROVSUN Ice Maker Machine Countertop, Make 44lb...             3.7
# 1  HANSGO Egg Holder for Refrigerator, Deviled Eg...             4.2
# 2  Clothes Dryer Drum Slide, General Electric, Ho...             3.5
# 3  154567702 Dishwasher Lower Wash Arm Assembly f...             4.5
# 4                        Whirlpool W10918546 Igniter             3.8
#
#    rating_number                                           features  \
# 0             61  [【Quick Ice Making】This countertop ice machine...
# 1             75  [Plastic, Practical Kitchen Storage - Our egg ...
# 2             18                                                 []
# 3             26  [MODEL NUMBER:154567702 Dishwasher Lower Wash ...
# 4             12          [This is a Genuine OEM Replacement Part.]
#
#                                          description  price  \
# 0                                                 []    NaN
# 1                                                 []    NaN
# 2  [Brand new dryer drum slide, replaces General ...    NaN
# 3  [MODEL NUMBER:154567702 Dishwasher Lower Wash ...    NaN
# 4                                [Whirlpool Igniter]  25.07
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
# 2  [{'thumb': 'https://m.media-amazon.com/images/...
# 3  [{'thumb': 'https://m.media-amazon.com/images/...
# 4  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos      store  \
# 0  [{'title': 'Our Point of View on the Euhomy Ic...     ROVSUN
# 1  [{'title': '10 Eggs Egg Holder for Refrigerato...     HANSGO
# 2                                                 []         GE
# 3                                                 []    folosem
# 4                                                 []  Whirlpool
#
#                                           categories  \
# 0  [Appliances, Refrigerators, Freezers & Ice Mak...
# 1  [Appliances, Parts & Accessories, Refrigerator...
# 2                  [Appliances, Parts & Accessories]
# 3  [Appliances, Parts & Accessories, Dryer Parts ...
# 4                  [Appliances, Parts & Accessories]
#
#                                              details parent_asin  \
# 0  {'Brand': 'ROVSUN', 'Model Name': 'ICM-2005', ...  B08Z743RRD
# 1  {'Manufacturer': 'HANSGO', 'Part Number': 'HAN...  B097BQDGHJ
# 2  {'Manufacturer': 'RPI', 'Part Number': 'WE1M33...  B00IN9AGAE
# 3  {'Manufacturer': 'folosem', 'Part Number': '15...  B0C7K98JZS
# 4  {'Manufacturer': 'Whirlpool', 'Part Number': '...  B07QZHQTVJ
#
#   bought_together subtitle author
# 0            None      NaN    NaN
# 1            None      NaN    NaN
# 2            None      NaN    NaN
# 3            None      NaN    NaN
# 4            None      NaN    NaN

# %% [markdown]
# ## Review data

# %%
file_path = 'data/review_data.jsonl'
data = []

# %%
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            data.append(json.loads(line))
        except json.JSONDecodeError:
            continue

df_review = pd.DataFrame(data)
df_review.head(5)
# Out:
#    rating              title  \
# 0     5.0         Work great
# 1     5.0  excellent product
# 2     5.0    Happy customer!
# 3     5.0      Amazing value
# 4     5.0        Dryer parts
#
#                                                 text images        asin  \
# 0              work great. use a new one every month     []  B01N0TQ0OH
# 1                            Little on the thin side     []  B07DD2DMXB
# 2                   Quick delivery, fixed the issue!     []  B082W3Z9YK
# 3  I wasn't sure whether these were worth it or n...     []  B078W2BJY8
# 4  Easy to install got the product expected to re...     []  B08C9LPCQV
#
#   parent_asin                       user_id      timestamp  helpful_vote  \
# 0  B01N0TQ0OH  AGKHLEW2SOWHNMFQIJGBECAF7INQ  1519317108692             0
# 1  B07DD37QPZ  AHWWLSPCJMALVHDDVSUGICL6RUCA  1664746863446             0
# 2  B082W3Z9YK  AHZIJGKEWRTAEOZ673G5B3SNXEGQ  1607225435363             0
# 3  B078W2BJY8  AFGUPTDFAWOHHL4LZDV27ERDNOYQ  1534104184306             0
# 4  B08C9LPCQV  AELFJFAXQERUSMTXJQ6SYFFRDWMA  1620176603754             0
#
#    verified_purchase
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True

# %% [markdown]
# # Data Merge

# %%
# Merge two datasets on the common 'parent_asin' column 
# 'how=inner' argument used to ensure that only rows with matching 'parent_asin' values in both datasets are included in the result 
# inner: use intersection of keys from both frames

merged_df = pd.merge(df_review, df_meta, on='parent_asin', how='inner')

# %%
merged_df.head(10)
# Out:
#    rating                            title_x  \
# 0     5.0                         Work great
# 1     5.0                  excellent product
# 2     5.0                    Happy customer!
# 3     5.0                      Amazing value
# 4     5.0                        Dryer parts
# 5     5.0  DO NOT purchase this ice machine.
# 6     2.0            They don't fit properly
# 7     5.0                         Five Stars
# 8     5.0                         Five Stars
# 9     2.0             Company is phenomenal.
#
#                                                 text images_x        asin  \
# 0              work great. use a new one every month       []  B01N0TQ0OH
# 1                            Little on the thin side       []  B07DD2DMXB
# 2                   Quick delivery, fixed the issue!       []  B082W3Z9YK
# 3  I wasn't sure whether these were worth it or n...       []  B078W2BJY8
# 4  Easy to install got the product expected to re...       []  B08C9LPCQV
# 5  After buying this ice machine just 15 months a...       []  B08D6RFV6D
# 6                               Not the best quality       []  B001TH7GZA
# 7    Part came quickly and fit my LG dryer.  Thanks!       []  B00AF7WZTM
# 8  Always arrive in a fast manner.  Descriptions ...       []  B001H05AXY
# 9  The company responded very quickly. Refunded p...       []  B085C6C7WH
#
#   parent_asin                       user_id      timestamp  helpful_vote  \
# 0  B01N0TQ0OH  AGKHLEW2SOWHNMFQIJGBECAF7INQ  1519317108692             0
# 1  B07DD37QPZ  AHWWLSPCJMALVHDDVSUGICL6RUCA  1664746863446             0
# 2  B082W3Z9YK  AHZIJGKEWRTAEOZ673G5B3SNXEGQ  1607225435363             0
# 3  B078W2BJY8  AFGUPTDFAWOHHL4LZDV27ERDNOYQ  1534104184306             0
# 4  B08C9LPCQV  AELFJFAXQERUSMTXJQ6SYFFRDWMA  1620176603754             0
# 5  B099ZKQJHK  AEUH4EH6XHROLT7UZPUYU2YKTYMA  1663078878875             0
# 6  B001TH7H0O  AHCV2CNCOCG6WECDROOUYPDZIFEQ  1610219023865             0
# 7  B00AF7WZTM  AH6PLOGWYIVIWLJTY756BHNFD4YA  1480334300000             0
# 8  B001H05AXY  AGCIVNDDRX3PXIUINEG4NCRGWCRA  1427130850000             0
# 9  B085C6C7WH  AFUOYIZBU3MTBOLYKOJE5Z35MBDA  1630449561325             0
#
#    verified_purchase  ...                                        description  \
# 0               True  ...                                                 []
# 1               True  ...                                                 []
# 2               True  ...                                                 []
# 3               True  ...  [FilterLogic FL-RF13 Replacement Refrigerator ...
# 4               True  ...                                                 []
# 5               True  ...  [2-in-1 ice maker, you can get ice water while...
# 6               True  ...                                                 []
# 7               True  ...  [Product Description, This high quality Genuin...
# 8               True  ...  [Maytag Amana Whirlpool Refrigerator Icemaker ...
# 9               True  ...                                                 []
#
#    price                                           images_y  \
# 0   9.99  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  22.99  [{'thumb': 'https://m.media-amazon.com/images/...
# 2    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 3    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 4    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 5    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 6    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 7  46.27  [{'thumb': 'https://m.media-amazon.com/images/...
# 8    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 9    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos             store  \
# 0  [{'title': 'Mr Coffee Water Filter Instruction...            Geesta
# 1  [{'title': 'How To Install An Indoor Dryer Ven...  Essential Values
# 2  [{'title': 'Blutoget make life more convenient...           Romalon
# 3  [{'title': 'Overbest NSF Certified Refrigerato...       FilterLogic
# 4  [{'title': 'Your Dryer Has Heating Problem?', ...           Sikawai
# 5  [{'title': 'Poor fill design and not made for ...          COOLLIFE
# 6  [{'title': 'Blutoget creates a happy life for ...            Stanco
# 7  [{'title': 'Whole Parts General Video', 'url':...                LG
# 8                                                 []             AMANA
# 9                                                 []          Northair
#
#                                           categories  \
# 0  [Small Appliance Parts & Accessories, Coffee &...
# 1  [Appliances, Parts & Accessories, Dryer Parts ...
# 2  [Appliances, Parts & Accessories, Dryer Parts ...
# 3  [Appliances, Parts & Accessories, Refrigerator...
# 4  [Appliances, Parts & Accessories, Dryer Parts ...
# 5  [Appliances, Refrigerators, Freezers & Ice Mak...
# 6  [Appliances, Parts & Accessories, Range Parts ...
# 7  [Appliances, Parts & Accessories, Dryer Parts ...
# 8                  [Appliances, Parts & Accessories]
# 9  [Appliances, Refrigerators, Freezers & Ice Mak...
#
#                                              details bought_together subtitle  \
# 0  {'Manufacturer': 'Geesta', 'Part Number': 'Gee...            None      NaN
# 1  {'Manufacturer': 'Essential Values', 'Part Num...            None      NaN
# 2  {'Manufacturer': 'Romalon', 'Part Number': '27...            None      NaN
# 3  {'Material': 'Carbon,Coconut Shell', 'Product ...            None      NaN
# 4  {'Part Number': '279816', 'Item Weight': '1.8 ...            None      NaN
# 5  {'Brand': 'COOLLIFE', 'Model Name': 'Counterto...            None      NaN
# 6  {'Product Dimensions': '9.75 x 9.75 x 2.5 inch...            None      NaN
# 7  {'Brand Name': 'LG', 'Model Info': '4774EL2001...            None      NaN
# 8  {'Manufacturer': 'Amana', 'Part Number': 'Wate...            None      NaN
# 9  {'Brand': 'Northair', 'Model Name': '2 in1 Ice...            None      NaN
#
#   author
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
#
# [10 rows x 25 columns]

# %%
# For timestamp, we need to convert the current format to YYYY-M-D type

merged_df['datetime'] = pd.to_datetime(merged_df['timestamp'], unit='ms')

# If the timestamp is already in seconds, you can use the code below
# merged_df['datetime'] = pd.to_datetime(merged_df['timestamp'], unit='s')
merged_df.head(5)
# Out:
#    rating            title_x  \
# 0     5.0         Work great
# 1     5.0  excellent product
# 2     5.0    Happy customer!
# 3     5.0      Amazing value
# 4     5.0        Dryer parts
#
#                                                 text images_x        asin  \
# 0              work great. use a new one every month       []  B01N0TQ0OH
# 1                            Little on the thin side       []  B07DD2DMXB
# 2                   Quick delivery, fixed the issue!       []  B082W3Z9YK
# 3  I wasn't sure whether these were worth it or n...       []  B078W2BJY8
# 4  Easy to install got the product expected to re...       []  B08C9LPCQV
#
#   parent_asin                       user_id      timestamp  helpful_vote  \
# 0  B01N0TQ0OH  AGKHLEW2SOWHNMFQIJGBECAF7INQ  1519317108692             0
# 1  B07DD37QPZ  AHWWLSPCJMALVHDDVSUGICL6RUCA  1664746863446             0
# 2  B082W3Z9YK  AHZIJGKEWRTAEOZ673G5B3SNXEGQ  1607225435363             0
# 3  B078W2BJY8  AFGUPTDFAWOHHL4LZDV27ERDNOYQ  1534104184306             0
# 4  B08C9LPCQV  AELFJFAXQERUSMTXJQ6SYFFRDWMA  1620176603754             0
#
#    verified_purchase  ...  price  \
# 0               True  ...   9.99
# 1               True  ...  22.99
# 2               True  ...    NaN
# 3               True  ...    NaN
# 4               True  ...    NaN
#
#                                             images_y  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
# 2  [{'thumb': 'https://m.media-amazon.com/images/...
# 3  [{'thumb': 'https://m.media-amazon.com/images/...
# 4  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos             store  \
# 0  [{'title': 'Mr Coffee Water Filter Instruction...            Geesta
# 1  [{'title': 'How To Install An Indoor Dryer Ven...  Essential Values
# 2  [{'title': 'Blutoget make life more convenient...           Romalon
# 3  [{'title': 'Overbest NSF Certified Refrigerato...       FilterLogic
# 4  [{'title': 'Your Dryer Has Heating Problem?', ...           Sikawai
#
#                                           categories  \
# 0  [Small Appliance Parts & Accessories, Coffee &...
# 1  [Appliances, Parts & Accessories, Dryer Parts ...
# 2  [Appliances, Parts & Accessories, Dryer Parts ...
# 3  [Appliances, Parts & Accessories, Refrigerator...
# 4  [Appliances, Parts & Accessories, Dryer Parts ...
#
#                                              details  bought_together  \
# 0  {'Manufacturer': 'Geesta', 'Part Number': 'Gee...             None
# 1  {'Manufacturer': 'Essential Values', 'Part Num...             None
# 2  {'Manufacturer': 'Romalon', 'Part Number': '27...             None
# 3  {'Material': 'Carbon,Coconut Shell', 'Product ...             None
# 4  {'Part Number': '279816', 'Item Weight': '1.8 ...             None
#
#   subtitle author                datetime
# 0      NaN    NaN 2018-02-22 16:31:48.692
# 1      NaN    NaN 2022-10-02 21:41:03.446
# 2      NaN    NaN 2020-12-06 03:30:35.363
# 3      NaN    NaN 2018-08-12 20:03:04.306
# 4      NaN    NaN 2021-05-05 01:03:23.754
#
# [5 rows x 26 columns]

# %%
merged_df.to_csv('data/merged_df_rec.csv', index=False)

# %% [markdown]
# # Filter Dataset

# %%
# Load dataset

df = pd.read_csv('data/merged_df_rec.csv')
# Out:
# C:\Users\Hyeon\AppData\Local\Temp\ipykernel_46024\75341038.py:3: DtypeWarning: Columns (23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/merged_df_rec.csv')

# %%
# Filter columns 

df_rec = df[['parent_asin', 'main_category', 'user_id', 'title_y', 'title_x', 'images_y', 'datetime', 'text', 'rating', 'rating_number', 'features', 'description', 'price', 'store', 'categories', 'details']]
                      
df_rec.head(20)
# Out:
#    parent_asin             main_category                       user_id  \
# 0   B01N0TQ0OH  Tools & Home Improvement  AGKHLEW2SOWHNMFQIJGBECAF7INQ
# 1   B07DD37QPZ  Tools & Home Improvement  AHWWLSPCJMALVHDDVSUGICL6RUCA
# 2   B082W3Z9YK  Tools & Home Improvement  AHZIJGKEWRTAEOZ673G5B3SNXEGQ
# 3   B078W2BJY8               Amazon Home  AFGUPTDFAWOHHL4LZDV27ERDNOYQ
# 4   B08C9LPCQV  Tools & Home Improvement  AELFJFAXQERUSMTXJQ6SYFFRDWMA
# 5   B099ZKQJHK   Industrial & Scientific  AEUH4EH6XHROLT7UZPUYU2YKTYMA
# 6   B001TH7H0O  Tools & Home Improvement  AHCV2CNCOCG6WECDROOUYPDZIFEQ
# 7   B00AF7WZTM                Appliances  AH6PLOGWYIVIWLJTY756BHNFD4YA
# 8   B001H05AXY  Tools & Home Improvement  AGCIVNDDRX3PXIUINEG4NCRGWCRA
# 9   B085C6C7WH                Appliances  AFUOYIZBU3MTBOLYKOJE5Z35MBDA
# 10  B09CBF2XCF         Sports & Outdoors  AHPUT3ITXCHQJO7OMF74LEMYHIVA
# 11  B09W5PMK5X                Appliances  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 12  B07BFGZQ65               Amazon Home  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 13  B01HIT0VMW               Amazon Home  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 14  B072JXR3MW               Amazon Home  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 15  B08FDB6W59  Tools & Home Improvement  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 16  B00EORXEUS               Amazon Home  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 17  B07VN6QRQL               Amazon Home  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 18  B016TZKU54               Amazon Home  AGUMKAETPKF5G37FKT6CXLBRPOAA
# 19  B08X9GYJLM               Amazon Home  AE7Y5RLYIKHOZB5NKKOEKYG2SPSQ
#
#                                               title_y  \
# 0   Geesta 12-Pack Premium Activated Charcoal Wate...
# 1   Essential Values 18 Pack Compatible Replacemen...
# 2   279838 Dryer Heating Element by Romalon with R...
# 3   Filterlogic UKF8001 Water Filter, Replacement ...
# 4   Sikawai 279816 Dryer Thermal Cut-off Kit Repla...
# 5   COOLLIFE Compact Countertop Ice Maker Machine ...
# 6   Stanco 5557 Drip Bowl Universal, Porcelain coa...
# 7   LG 4774EL2001A Genuine OEM Door Hinge for LG D...
# 8   Amana Refrigerator Icemaker Water Valve R00002...
# 9   Northair 2 in1 Ice Maker and Water Dispenser w...
# 10  Perfect Pod EZ-Scoop Coffee Scooper & Funnel f...
# 11  COMFEE’ Washing Machine 2.4 Cu.ft LED Portable...
# 12  Blendin Replacement Pod Holder Part with Exit ...
# 13  Cold Brew Coffee Maker, Iced Coffee & Tea Make...
# 14  MG Coffee Refillable Capsule Reusable Capsules...
# 15  Deflecto Dryer Lint Trap Kit, Indoor Venting w...
# 16  Brew Rite Wrap Around Percolator Coffee Filter...
# 17         Melitta 3.5 Inch White Disc Coffee Filters
# 18  DI ORO MaxBrew Keurig Reusable K Cup Coffee Fi...
# 19  Cafe Supreme Reusable Single Serve Coffee Filt...
#
#                                               title_x  \
# 0                                          Work great
# 1                                   excellent product
# 2                                     Happy customer!
# 3                                       Amazing value
# 4                                         Dryer parts
# 5                   DO NOT purchase this ice machine.
# 6                             They don't fit properly
# 7                                          Five Stars
# 8                                          Five Stars
# 9                              Company is phenomenal.
# 10                             Easy use coffee scoop.
# 11                                     so far so good
# 12                                        Perfect !!!
# 13                            WOW im impressed !!!!!!
# 14                                       awesome deal
# 15                                              great
# 16                                               Good
# 17                                             horrid
# 18  Tried with a finer grind as described on the i...
# 19                                Use your own Coffee
#
#                                              images_y  \
# 0   [{'thumb': 'https://m.media-amazon.com/images/...
# 1   [{'thumb': 'https://m.media-amazon.com/images/...
# 2   [{'thumb': 'https://m.media-amazon.com/images/...
# 3   [{'thumb': 'https://m.media-amazon.com/images/...
# 4   [{'thumb': 'https://m.media-amazon.com/images/...
# 5   [{'thumb': 'https://m.media-amazon.com/images/...
# 6   [{'thumb': 'https://m.media-amazon.com/images/...
# 7   [{'thumb': 'https://m.media-amazon.com/images/...
# 8   [{'thumb': 'https://m.media-amazon.com/images/...
# 9   [{'thumb': 'https://m.media-amazon.com/images/...
# 10  [{'thumb': 'https://m.media-amazon.com/images/...
# 11  [{'thumb': 'https://m.media-amazon.com/images/...
# 12  [{'thumb': 'https://m.media-amazon.com/images/...
# 13  [{'thumb': 'https://m.media-amazon.com/images/...
# 14  [{'thumb': 'https://m.media-amazon.com/images/...
# 15  [{'thumb': 'https://m.media-amazon.com/images/...
# 16  [{'thumb': 'https://m.media-amazon.com/images/...
# 17  [{'thumb': 'https://m.media-amazon.com/images/...
# 18  [{'thumb': 'https://m.media-amazon.com/images/...
# 19  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                    datetime  \
# 0   2018-02-22 16:31:48.692
# 1   2022-10-02 21:41:03.446
# 2   2020-12-06 03:30:35.363
# 3   2018-08-12 20:03:04.306
# 4   2021-05-05 01:03:23.754
# 5   2022-09-13 14:21:18.875
# 6   2021-01-09 19:03:43.865
# 7   2016-11-28 11:58:20.000
# 8   2015-03-23 17:14:10.000
# 9   2021-08-31 22:39:21.325
# 10  2021-03-17 21:09:01.916
# 11  2022-04-17 00:01:07.807
# 12  2018-07-02 21:18:12.904
# 13  2018-05-28 06:45:58.389
# 14  2018-04-28 21:52:00.094
# 15  2017-12-18 00:35:34.944
# 16  2017-07-22 23:53:29.568
# 17  2017-07-15 03:42:32.427
# 18  2017-10-07 19:44:09.870
# 19  2021-08-28 23:48:16.004
#
#                                                  text  rating  rating_number  \
# 0               work great. use a new one every month     5.0           4939
# 1                             Little on the thin side     5.0           3186
# 2                    Quick delivery, fixed the issue!     5.0            444
# 3   I wasn't sure whether these were worth it or n...     5.0            355
# 4   Easy to install got the product expected to re...     5.0             55
# 5   After buying this ice machine just 15 months a...     5.0            506
# 6                                Not the best quality     2.0          11035
# 7     Part came quickly and fit my LG dryer.  Thanks!     5.0            129
# 8   Always arrive in a fast manner.  Descriptions ...     5.0             59
# 9   The company responded very quickly. Refunded p...     2.0            223
# 10  Love little kitchen gadgets.  Would recommend ...     4.0          15159
# 11  but i havent had it long  a year down the road...     5.0             35
# 12  i have a K15 and was concerned it wouldnt fit ...     5.0           4576
# 13  im excited to see how the coffee comes out  i ...     5.0           1032
# 14  what a great deal and it even had a little cof...     5.0             25
# 15                                       worked great     5.0           5428
# 16  these are OK  a little tooo big  but they work...     4.0           1057
# 17  thin and chinsy i could even bother returning ...     1.0           3679
# 18  The filter did not fit in my Keurig K50. When ...     2.0           2914
# 19  This was hard to find out how to put it into t...     3.0           3767
#
#                                              features  \
# 0   ['EXCEPTIONAL QUALITY AND VALUE: Brew clean, d...
# 1   ['BEST VALUE - Our 18 Pack Of Fine Polyester R...
# 2   ["★【BUY WITH CONFIDENCE】 For any reason you're...
# 3   ['The replacement for Maytag UKF8001 refrigera...
# 4                                                  []
# 5   ['Highly Efficient Ice Production - Countertop...
# 6   ['Fits most plug-in electric ranges * Fits mos...
# 7   ['The LG 4774EL2001A Door Hinge is a genuine O...
# 8   ['Water Valve Inlet allows water exchange and ...
# 9   ['【2-in-1 Ice Maker】 2-in-1 Water Dispenser wi...
# 10  ['Coffee Scoop with Integrated Funnel- fastest...
# 11  ["AUTO CLEAN - COMFEE' 2.4 Cu.ft portable wash...
# 12  ['WIDELY COMPATIBLE With KEURIG: This K Cup Ho...
# 13  ['Make Cold Brew Coffee, Iced Tea & Infused Wa...
# 14  ['Reusbale- can be use over hundred time,user ...
# 15  ['Designed For Safe Indoor Dryer Venting Where...
# 16  ['Made in USA', '55 ct Wraparound Style Filter...
# 17  ['Each package contains 100 Filters (200 total...
# 18  ['PURFLOW 24K GOLD MAXBREW FILTER – Our aesthe...
# 19  ['Save Money - Our Cafe Supreme reusable k cup...
#
#                                           description   price  \
# 0                                                  []    9.99
# 1                                                  []   22.99
# 2                                                  []     NaN
# 3   ['FilterLogic FL-RF13 Replacement Refrigerator...     NaN
# 4                                                  []     NaN
# 5   ["2-in-1 ice maker, you can get ice water whil...     NaN
# 6                                                  []     NaN
# 7   ['Product Description', "This high quality Gen...   46.27
# 8   ['Maytag Amana Whirlpool Refrigerator Icemaker...     NaN
# 9                                                  []     NaN
# 10                                                 []    8.99
# 11  ['Feeling unsafe going to Laundromat? Tired of...  399.00
# 12  ["Welcome to Blendin! We give you dependable K...    9.99
# 13                                                 []     NaN
# 14                                                 []    8.99
# 15  ['Product Description', 'When Outside Venting ...   18.00
# 16  ['In order to provide superior coffee filtrati...    5.99
# 17  ["Specially designed to let coffee's full flav...    6.18
# 18                                                 []   11.97
# 19                                                 []     NaN
#
#                store                                         categories  \
# 0             Geesta  ['Small Appliance Parts & Accessories', 'Coffe...
# 1   Essential Values  ['Appliances', 'Parts & Accessories', 'Dryer P...
# 2            Romalon  ['Appliances', 'Parts & Accessories', 'Dryer P...
# 3        FilterLogic  ['Appliances', 'Parts & Accessories', 'Refrige...
# 4            Sikawai  ['Appliances', 'Parts & Accessories', 'Dryer P...
# 5           COOLLIFE  ['Appliances', 'Refrigerators, Freezers & Ice ...
# 6             Stanco  ['Appliances', 'Parts & Accessories', 'Range P...
# 7                 LG  ['Appliances', 'Parts & Accessories', 'Dryer P...
# 8              AMANA              ['Appliances', 'Parts & Accessories']
# 9           Northair  ['Appliances', 'Refrigerators, Freezers & Ice ...
# 10       PERFECT POD  ['Small Appliance Parts & Accessories', 'Coffe...
# 11           COMFEE'  ['Appliances', 'Laundry Appliances', 'Washers ...
# 12           Blendin  ['Small Appliance Parts & Accessories', 'Coffe...
# 13              Zell  ['Small Appliance Parts & Accessories', 'Coffe...
# 14         MG Coffee  ['Small Appliance Parts & Accessories', 'Coffe...
# 15          Deflecto  ['Appliances', 'Parts & Accessories', 'Dryer P...
# 16         Brew Rite  ['Small Appliance Parts & Accessories', 'Coffe...
# 17           Melitta  ['Small Appliance Parts & Accessories', 'Coffe...
# 18      di Oro Caffè  ['Small Appliance Parts & Accessories', 'Coffe...
# 19       PERFECT POD  ['Small Appliance Parts & Accessories', 'Coffe...
#
#                                               details
# 0   {'Manufacturer': 'Geesta', 'Part Number': 'Gee...
# 1   {'Manufacturer': 'Essential Values', 'Part Num...
# 2   {'Manufacturer': 'Romalon', 'Part Number': '27...
# 3   {'Material': 'Carbon,Coconut Shell', 'Product ...
# 4   {'Part Number': '279816', 'Item Weight': '1.8 ...
# 5   {'Brand': 'COOLLIFE', 'Model Name': 'Counterto...
# 6   {'Product Dimensions': '9.75 x 9.75 x 2.5 inch...
# 7   {'Brand Name': 'LG', 'Model Info': '4774EL2001...
# 8   {'Manufacturer': 'Amana', 'Part Number': 'Wate...
# 9   {'Brand': 'Northair', 'Model Name': '2 in1 Ice...
# 10  {'Package Dimensions': '7.4 x 2.28 x 2.13 inch...
# 11  {'Brand Name': "COMFEE'", 'Model Info': 'CLV24...
# 12  {'Product Dimensions': '4.7"L x 3.5"W x 2.5"H'...
# 13  {'Brand': 'Zell', 'Capacity': '2 Pounds', 'Col...
# 14  {'Material': 'Polypropylene', 'Compatible Devi...
# 15  {'Manufacturer': 'DEFLECTO', 'Part Number': 'L...
# 16  {'Product Dimensions': '9.5 x 9.5 x 0.1 inches...
# 17  {'Item Package Dimensions L x W x H': '5.28 x ...
# 18  {'Product Dimensions': '4.09 x 2.8 x 2.8 inche...
# 19  {'Package Dimensions': '9.5 x 6.5 x 4.5 inches...

# %%
# rename columns

df_rec.rename(columns={'title_y': 'product_name', 'title_x': 'review_title', 'text': 'review_text', 'parent_asin': 'product_id', 'images_y': 'images'}, inplace=True)
# Out:
# C:\Users\Hyeon\AppData\Local\Temp\ipykernel_46024\1581941744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rec.rename(columns={'title_y': 'product_name', 'title_x': 'review_title', 'text': 'review_text', 'parent_asin': 'product_id', 'images_y': 'images'}, inplace=True)

# %%
df_rec.head(5)
# Out:
#    product_id             main_category                       user_id  \
# 0  B01N0TQ0OH  Tools & Home Improvement  AGKHLEW2SOWHNMFQIJGBECAF7INQ
# 1  B07DD37QPZ  Tools & Home Improvement  AHWWLSPCJMALVHDDVSUGICL6RUCA
# 2  B082W3Z9YK  Tools & Home Improvement  AHZIJGKEWRTAEOZ673G5B3SNXEGQ
# 3  B078W2BJY8               Amazon Home  AFGUPTDFAWOHHL4LZDV27ERDNOYQ
# 4  B08C9LPCQV  Tools & Home Improvement  AELFJFAXQERUSMTXJQ6SYFFRDWMA
#
#                                         product_name       review_title  \
# 0  Geesta 12-Pack Premium Activated Charcoal Wate...         Work great
# 1  Essential Values 18 Pack Compatible Replacemen...  excellent product
# 2  279838 Dryer Heating Element by Romalon with R...    Happy customer!
# 3  Filterlogic UKF8001 Water Filter, Replacement ...      Amazing value
# 4  Sikawai 279816 Dryer Thermal Cut-off Kit Repla...        Dryer parts
#
#                                               images                 datetime  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...  2018-02-22 16:31:48.692
# 1  [{'thumb': 'https://m.media-amazon.com/images/...  2022-10-02 21:41:03.446
# 2  [{'thumb': 'https://m.media-amazon.com/images/...  2020-12-06 03:30:35.363
# 3  [{'thumb': 'https://m.media-amazon.com/images/...  2018-08-12 20:03:04.306
# 4  [{'thumb': 'https://m.media-amazon.com/images/...  2021-05-05 01:03:23.754
#
#                                          review_text  rating  rating_number  \
# 0              work great. use a new one every month     5.0           4939
# 1                            Little on the thin side     5.0           3186
# 2                   Quick delivery, fixed the issue!     5.0            444
# 3  I wasn't sure whether these were worth it or n...     5.0            355
# 4  Easy to install got the product expected to re...     5.0             55
#
#                                             features  \
# 0  ['EXCEPTIONAL QUALITY AND VALUE: Brew clean, d...
# 1  ['BEST VALUE - Our 18 Pack Of Fine Polyester R...
# 2  ["★【BUY WITH CONFIDENCE】 For any reason you're...
# 3  ['The replacement for Maytag UKF8001 refrigera...
# 4                                                 []
#
#                                          description  price             store  \
# 0                                                 []   9.99            Geesta
# 1                                                 []  22.99  Essential Values
# 2                                                 []    NaN           Romalon
# 3  ['FilterLogic FL-RF13 Replacement Refrigerator...    NaN       FilterLogic
# 4                                                 []    NaN           Sikawai
#
#                                           categories  \
# 0  ['Small Appliance Parts & Accessories', 'Coffe...
# 1  ['Appliances', 'Parts & Accessories', 'Dryer P...
# 2  ['Appliances', 'Parts & Accessories', 'Dryer P...
# 3  ['Appliances', 'Parts & Accessories', 'Refrige...
# 4  ['Appliances', 'Parts & Accessories', 'Dryer P...
#
#                                              details
# 0  {'Manufacturer': 'Geesta', 'Part Number': 'Gee...
# 1  {'Manufacturer': 'Essential Values', 'Part Num...
# 2  {'Manufacturer': 'Romalon', 'Part Number': '27...
# 3  {'Material': 'Carbon,Coconut Shell', 'Product ...
# 4  {'Part Number': '279816', 'Item Weight': '1.8 ...

# %%
df_rec.shape
# Out:
# (2128605, 16)

# %%
# Check duplicates

duplicate_rows = df_rec[df_rec.duplicated()]
print(duplicate_rows.shape)
# Out:
# (22657, 16)

# %%
# Remove duplicates 

df_rec = df_rec.drop_duplicates()

# %%
# re-check duplicates after removal 

duplicate_rows = df_rec[df_rec.duplicated()]
print(duplicate_rows.shape)
# Out:
# (0, 16)

# %%
# Check missing data 

df_rec.isnull().sum()
# Out:
# product_id            0
# main_category     28172
# user_id               0
# product_name         15
# review_title        865
# images                0
# datetime              0
# review_text         931
# rating                0
# rating_number         0
# features              0
# description           0
# price            522690
# store              6030
# categories            0
# details               0
# dtype: int64

# %%
# remove missing data 

df_rec = df_rec.dropna()

# %%
# Re-check missing value after removal 

df_rec.isnull().sum()
# Out:
# product_id       0
# main_category    0
# user_id          0
# product_name     0
# review_title     0
# images           0
# datetime         0
# review_text      0
# rating           0
# rating_number    0
# features         0
# description      0
# price            0
# store            0
# categories       0
# details          0
# dtype: int64

# %%
# unique category check

category_unique = df_rec['main_category'].unique()
print(category_unique)
print(f"Total unique 'category' in the reviews dataset: {len(category_unique)}")
# Out:
# ['Tools & Home Improvement' 'Appliances' 'Sports & Outdoors' 'Amazon Home'
#  'Industrial & Scientific' 'Health & Personal Care' 'Automotive'
#  'Office Products' 'Grocery' 'Baby' 'Books' 'AMAZON FASHION'
#  'All Electronics' 'Pet Supplies' 'Camera & Photo' 'Toys & Games'
#  'All Beauty' 'Home Audio & Theater' 'Cell Phones & Accessories'
#  'Arts, Crafts & Sewing' 'Portable Audio & Accessories' 'Computers'
#  'Musical Instruments' 'Car Electronics' 'Movies & TV' 'Video Games'
#  'Digital Music']
# Total unique 'category' in the reviews dataset: 27

# %%
# unique product name check

product_title_unique = df_rec['product_name'].unique()
print(product_title_unique)
print(f"Total unique 'products' in the reviews dataset: {len(product_title_unique)}")
# Out:
# ['Geesta 12-Pack Premium Activated Charcoal Water Filter Disk for All Mr. Coffee Models'
#  'Essential Values 18 Pack Compatible Replacement Filters (90 Dryer Loads Total) for Bettervent Indoor Dryer Vent'
#  'LG 4774EL2001A Genuine OEM Door Hinge for LG Dryers' ...
#  '3-Pack Replacement for Kenmore/Sears 10650512003 Refrigerator Water Filter - Compatible with Kenmore/Sears 46-9002 Fridge Water Filter Cartridge'
#  'W10161215 Lower Rack & wheels Fits for Whirlpool Dishwasher 8561705 8519478 8539225'
#  'Primeco 4417EA1002K Washer Motor Stator Compatible for Washer Made by OEM Parts Manufacturer AP5229785, 1519490, 4417EA1002X, AH3522950, EA3522950, PS3522950']
# Total unique 'products' in the reviews dataset: 43471

# %% [markdown]
# # Content based Filtering

# %%
# Filter columns

df_rec = df_rec[['product_id', 'main_category', 'categories', 'user_id', 'product_name', 'images', 'datetime', 'rating', 'features', 'description', 'price']]
                      
df_rec.head(20)
# Out:
#     product_id             main_category  \
# 0   B01N0TQ0OH  Tools & Home Improvement
# 1   B07DD37QPZ  Tools & Home Improvement
# 7   B00AF7WZTM                Appliances
# 10  B09CBF2XCF         Sports & Outdoors
# 11  B09W5PMK5X                Appliances
# 12  B07BFGZQ65               Amazon Home
# 14  B072JXR3MW               Amazon Home
# 15  B08FDB6W59  Tools & Home Improvement
# 16  B00EORXEUS               Amazon Home
# 17  B07VN6QRQL               Amazon Home
# 18  B016TZKU54               Amazon Home
# 20  B08XP29S76  Tools & Home Improvement
# 21  B072JL5W21               Amazon Home
# 23  B003AXVADA               Amazon Home
# 24  B001TJ5380  Tools & Home Improvement
# 25  B082DQDDBV               Amazon Home
# 26  B077WCTV57               Amazon Home
# 27  B0BTV3G59T               Amazon Home
# 28  B084L49119               Amazon Home
# 30  B09DD2LZBY               Amazon Home
#
#                                            categories  \
# 0   ['Small Appliance Parts & Accessories', 'Coffe...
# 1   ['Appliances', 'Parts & Accessories', 'Dryer P...
# 7   ['Appliances', 'Parts & Accessories', 'Dryer P...
# 10  ['Small Appliance Parts & Accessories', 'Coffe...
# 11  ['Appliances', 'Laundry Appliances', 'Washers ...
# 12  ['Small Appliance Parts & Accessories', 'Coffe...
# 14  ['Small Appliance Parts & Accessories', 'Coffe...
# 15  ['Appliances', 'Parts & Accessories', 'Dryer P...
# 16  ['Small Appliance Parts & Accessories', 'Coffe...
# 17  ['Small Appliance Parts & Accessories', 'Coffe...
# 18  ['Small Appliance Parts & Accessories', 'Coffe...
# 20  ['Appliances', 'Parts & Accessories', 'Range P...
# 21  ['Small Appliance Parts & Accessories', 'Coffe...
# 23  ['Small Appliance Parts & Accessories', 'Coffe...
# 24  ['Appliances', 'Parts & Accessories', 'Refrige...
# 25  ['Small Appliance Parts & Accessories', 'Coffe...
# 26  ['Small Appliance Parts & Accessories', 'Coffe...
# 27  ['Small Appliance Parts & Accessories', 'Coffe...
# 28  ['Small Appliance Parts & Accessories', 'Coffe...
# 30  ['Small Appliance Parts & Accessories', 'Coffe...
#
#                          user_id  \
# 0   AGKHLEW2SOWHNMFQIJGBECAF7INQ
# 1   AHWWLSPCJMALVHDDVSUGICL6RUCA
# 7   AH6PLOGWYIVIWLJTY756BHNFD4YA
# 10  AHPUT3ITXCHQJO7OMF74LEMYHIVA
# 11  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 12  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 14  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 15  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 16  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 17  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 18  AGUMKAETPKF5G37FKT6CXLBRPOAA
# 20  AEYS7TG2WOZAB7NLRVGTM5XZIG3Q
# 21  AH2B7RFJ3JIFZX5A52WKNH2MVTYA
# 23  AHZ6XMOLEWA67S3TX7IWEXXGWSOA
# 24  AHZ6XMOLEWA67S3TX7IWEXXGWSOA
# 25  AFZUK3MTBIBEDQOPAK3OATUOUKLA
# 26  AFZUK3MTBIBEDQOPAK3OATUOUKLA
# 27  AFZUK3MTBIBEDQOPAK3OATUOUKLA
# 28  AFZUK3MTBIBEDQOPAK3OATUOUKLA
# 30  AFZUK3MTBIBEDQOPAK3OATUOUKLA
#
#                                          product_name  \
# 0   Geesta 12-Pack Premium Activated Charcoal Wate...
# 1   Essential Values 18 Pack Compatible Replacemen...
# 7   LG 4774EL2001A Genuine OEM Door Hinge for LG D...
# 10  Perfect Pod EZ-Scoop Coffee Scooper & Funnel f...
# 11  COMFEE’ Washing Machine 2.4 Cu.ft LED Portable...
# 12  Blendin Replacement Pod Holder Part with Exit ...
# 14  MG Coffee Refillable Capsule Reusable Capsules...
# 15  Deflecto Dryer Lint Trap Kit, Indoor Venting w...
# 16  Brew Rite Wrap Around Percolator Coffee Filter...
# 17         Melitta 3.5 Inch White Disc Coffee Filters
# 18  DI ORO MaxBrew Keurig Reusable K Cup Coffee Fi...
# 20  ITEMporia Silicone Stove Gap Covers (2 Pack), ...
# 21  K Cup Filters - Pack of 300 - Fits With All Re...
# 23  Rockline Industries Inc JR100 "4 Cup" 100-Coun...
# 24  WaterSentinel WSS-1 Refrigerator Replacement F...
# 25  Melitta Percolator Wrap-Around Coffee Filters,...
# 26    White Disc Coffee Filter, 100 Count (Pack of 6)
# 27  Perfect Pod EZ-Cup Filters by Perfect Pod (150...
# 28  EZ-Cup Stainless Steel Reusable K Cup Coffee P...
# 30  CAPMESSO Disposable Coffee Paper Filters, 200 ...
#
#                                                images  \
# 0   [{'thumb': 'https://m.media-amazon.com/images/...
# 1   [{'thumb': 'https://m.media-amazon.com/images/...
# 7   [{'thumb': 'https://m.media-amazon.com/images/...
# 10  [{'thumb': 'https://m.media-amazon.com/images/...
# 11  [{'thumb': 'https://m.media-amazon.com/images/...
# 12  [{'thumb': 'https://m.media-amazon.com/images/...
# 14  [{'thumb': 'https://m.media-amazon.com/images/...
# 15  [{'thumb': 'https://m.media-amazon.com/images/...
# 16  [{'thumb': 'https://m.media-amazon.com/images/...
# 17  [{'thumb': 'https://m.media-amazon.com/images/...
# 18  [{'thumb': 'https://m.media-amazon.com/images/...
# 20  [{'thumb': 'https://m.media-amazon.com/images/...
# 21  [{'thumb': 'https://m.media-amazon.com/images/...
# 23  [{'thumb': 'https://m.media-amazon.com/images/...
# 24  [{'thumb': 'https://m.media-amazon.com/images/...
# 25  [{'thumb': 'https://m.media-amazon.com/images/...
# 26  [{'thumb': 'https://m.media-amazon.com/images/...
# 27  [{'thumb': 'https://m.media-amazon.com/images/...
# 28  [{'thumb': 'https://m.media-amazon.com/images/...
# 30  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                    datetime  rating  \
# 0   2018-02-22 16:31:48.692     5.0
# 1   2022-10-02 21:41:03.446     5.0
# 7   2016-11-28 11:58:20.000     5.0
# 10  2021-03-17 21:09:01.916     4.0
# 11  2022-04-17 00:01:07.807     5.0
# 12  2018-07-02 21:18:12.904     5.0
# 14  2018-04-28 21:52:00.094     5.0
# 15  2017-12-18 00:35:34.944     5.0
# 16  2017-07-22 23:53:29.568     4.0
# 17  2017-07-15 03:42:32.427     1.0
# 18  2017-10-07 19:44:09.870     2.0
# 20  2019-08-02 22:21:10.633     5.0
# 21  2020-11-12 04:55:20.645     4.0
# 23  2017-02-21 01:55:05.000     5.0
# 24  2014-07-26 14:22:11.000     4.0
# 25  2023-02-08 21:26:23.448     5.0
# 26  2022-09-25 18:27:14.178     5.0
# 27  2022-04-21 18:26:26.703     5.0
# 28  2022-04-21 18:22:23.395     4.0
# 30  2019-11-23 03:24:26.566     5.0
#
#                                              features  \
# 0   ['EXCEPTIONAL QUALITY AND VALUE: Brew clean, d...
# 1   ['BEST VALUE - Our 18 Pack Of Fine Polyester R...
# 7   ['The LG 4774EL2001A Door Hinge is a genuine O...
# 10  ['Coffee Scoop with Integrated Funnel- fastest...
# 11  ["AUTO CLEAN - COMFEE' 2.4 Cu.ft portable wash...
# 12  ['WIDELY COMPATIBLE With KEURIG: This K Cup Ho...
# 14  ['Reusbale- can be use over hundred time,user ...
# 15  ['Designed For Safe Indoor Dryer Venting Where...
# 16  ['Made in USA', '55 ct Wraparound Style Filter...
# 17  ['Each package contains 100 Filters (200 total...
# 18  ['PURFLOW 24K GOLD MAXBREW FILTER – Our aesthe...
# 20  ['Silicone', 'KEEP THE YUCK OFF YOUR COUNTERTO...
# 21  ['Perfect Size Coffee Pod Filters: We have mad...
# 23  ['Brand:ROCKLINE INDUSTRIES INC', 'JR100 08500...
# 24  ['Made from Coconut Shell Carbon', 'Made in US...
# 25  ["Percolator Coffee Filters: These filters let...
# 26  ['6 Packs, 100 Disc Filters in each Pack, 3.5 ...
# 27  ['Allows the use of any coffee in your Keurig ...
# 28  ['All-In-1 Starter Kit – Everything you need t...
# 30  ['🌴KEURG FILTER: ECO SAFE MATERIAL: Our paper ...
#
#                                           description   price
# 0                                                  []    9.99
# 1                                                  []   22.99
# 7   ['Product Description', "This high quality Gen...   46.27
# 10                                                 []    8.99
# 11  ['Feeling unsafe going to Laundromat? Tired of...  399.00
# 12  ["Welcome to Blendin! We give you dependable K...    9.99
# 14                                                 []    8.99
# 15  ['Product Description', 'When Outside Venting ...   18.00
# 16  ['In order to provide superior coffee filtrati...    5.99
# 17  ["Specially designed to let coffee's full flav...    6.18
# 18                                                 []   11.97
# 20                                                 []    9.99
# 21                                                 []   19.99
# 23  ['Brand:ROCKLINE INDUSTRIES INC JR100 08500670...    6.34
# 24  ['Product Description', 'Filter Fits: Samsung ...   54.32
# 25  ["Our founder, Melitta Bentz, invented coffee ...   29.58
# 26     ['Melitta is the premier coffee filter maker']   12.00
# 27                                                 []   16.99
# 28                                                 []   16.99
# 30                                                 []   12.99

# %%
# check how many reviews are registered, per category 

review_counts = df_rec.groupby('main_category').size()
print(review_counts)
# Out:
# main_category
# AMAZON FASHION                     930
# All Beauty                         471
# All Electronics                   1956
# Amazon Home                     443516
# Appliances                      408604
# Arts, Crafts & Sewing              137
# Automotive                        6243
# Baby                              2224
# Books                              159
# Camera & Photo                    1698
# Car Electronics                     95
# Cell Phones & Accessories          505
# Computers                          228
# Digital Music                        1
# Grocery                          10581
# Health & Personal Care            5788
# Home Audio & Theater               440
# Industrial & Scientific          76509
# Movies & TV                          3
# Musical Instruments                270
# Office Products                   1189
# Pet Supplies                       343
# Portable Audio & Accessories       251
# Sports & Outdoors                 4177
# Tools & Home Improvement        603314
# Toys & Games                       360
# Video Games                          2
# dtype: int64

# %% [markdown]
# ### Recommendation for Appliances Categories

# %%
# we will create a recommendation system for products from Appliances category 

target_categories = [
    'Appliances',
]

# .isin() method for target categories
elec_df = df_rec[df_rec['main_category'].isin(target_categories)]
elec_df.head(5)
# Out:
#     product_id main_category  \
# 7   B00AF7WZTM    Appliances
# 11  B09W5PMK5X    Appliances
# 37  B00ECV6EEO    Appliances
# 57  B0C57WMPJQ    Appliances
# 89  B0C2HMPZRB    Appliances
#
#                                            categories  \
# 7   ['Appliances', 'Parts & Accessories', 'Dryer P...
# 11  ['Appliances', 'Laundry Appliances', 'Washers ...
# 37  ['Appliances', 'Parts & Accessories', 'Oven Pa...
# 57  ['Appliances', 'Refrigerators, Freezers & Ice ...
# 89  ['Appliances', 'Laundry Appliances', 'Washers ...
#
#                          user_id  \
# 7   AH6PLOGWYIVIWLJTY756BHNFD4YA
# 11  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 37  AE2TA5GQH4JI5RQ4W5H5PQOVYBGA
# 57  AGJXTLEOLLTIX5AAGFPBZ7CNNVOQ
# 89  AGYEAZK4OEYF2MSSTGJ5WNJDVZKA
#
#                                          product_name  \
# 7   LG 4774EL2001A Genuine OEM Door Hinge for LG D...
# 11  COMFEE’ Washing Machine 2.4 Cu.ft LED Portable...
# 37                 GE WB2X9719 Support Bracket Silver
# 57  Silonn Ice Makers Countertop, 9 Cubes Ready in...
# 89  COSTWAY Compact Laundry Dryer, 110V Electric P...
#
#                                                images  \
# 7   [{'thumb': 'https://m.media-amazon.com/images/...
# 11  [{'thumb': 'https://m.media-amazon.com/images/...
# 37  [{'thumb': 'https://m.media-amazon.com/images/...
# 57  [{'thumb': 'https://m.media-amazon.com/images/...
# 89  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                    datetime  rating  \
# 7   2016-11-28 11:58:20.000     5.0
# 11  2022-04-17 00:01:07.807     5.0
# 37  2020-05-24 20:10:39.354     1.0
# 57  2022-06-10 16:22:20.651     5.0
# 89  2019-09-23 22:44:56.891     5.0
#
#                                              features  \
# 7   ['The LG 4774EL2001A Door Hinge is a genuine O...
# 11  ["AUTO CLEAN - COMFEE' 2.4 Cu.ft portable wash...
# 37  ['The GE Appliances Broil Element Support is a...
# 57  ['Note : Please check the dimension and item w...
# 89  ['【Compact & Portable】The weight of this cloth...
#
#                                           description   price
# 7   ['Product Description', "This high quality Gen...   46.27
# 11  ['Feeling unsafe going to Laundromat? Tired of...  399.00
# 37  ['Product Description', 'The high quality GE A...    8.75
# 57  ['Ice in 6 mins - Self Cleaning - Portable - 2...   80.97
# 89                                                 []  259.99

# %%
elec_df.shape
# Out:
# (408604, 11)

# %%
# unique categories check

elec_category_unique = elec_df['categories'].unique()
print(elec_category_unique)
print(f"Total unique 'products' in the reviews dataset: {len(elec_category_unique)}")
# Out:
# ["['Appliances', 'Parts & Accessories', 'Dryer Parts & Accessories', 'Replacement Parts']"
#  "['Appliances', 'Laundry Appliances', 'Washers & Dryers', 'Portable Washers']"
#  "['Appliances', 'Parts & Accessories', 'Oven Parts & Accessories']"
#  "['Appliances', 'Refrigerators, Freezers & Ice Makers', 'Ice Makers']"
#  "['Appliances', 'Laundry Appliances', 'Washers & Dryers', 'Portable Dryers']"
#  "['Appliances', 'Refrigerators, Freezers & Ice Makers', 'Freezers', 'Chest Freezers']"
#  "['Appliances', 'Refrigerators, Freezers & Ice Makers', 'Refrigerators']"
#  "['Appliances', 'Parts & Accessories', 'Range Parts & Accessories', 'Drip Pans']"
#  "['Appliances', 'Dishwashers', 'Countertop Dishwashers']"
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories', 'Water Filters']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Range Hoods']"
#  "['Appliances', 'Refrigerators, Freezers & Ice Makers', 'Freezers', 'Upright Freezers']"
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories', 'Ice Makers']"
#  '[]'
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories', 'Egg Trays']"
#  "['Appliances', 'Parts & Accessories']"
#  "['Appliances', 'Parts & Accessories', 'Dishwasher Parts & Accessories', 'Hoses']"
#  "['Appliances', 'Parts & Accessories', 'Range Hood Parts & Accessories', 'Filters']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Cooktops']"
#  "['Appliances', 'Parts & Accessories', 'Range Parts & Accessories', 'Accessories']"
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories', 'Bins']"
#  "['Appliances', 'Parts & Accessories', 'Dryer Parts & Accessories', 'Vents']"
#  "['Appliances', 'Parts & Accessories', 'Dishwasher Parts & Accessories', 'Baskets']"
#  "['Appliances', 'Dishwashers', 'Built-In Dishwashers']"
#  "['Appliances', 'Laundry Appliances', 'Washers & Dryers', 'Stacked Washer & Dryer Units']"
#  "['Appliances', 'Parts & Accessories', 'Washer Parts & Accessories', 'Drain Pumps']"
#  "['Appliances', 'Parts & Accessories', 'Humidifier Parts & Accessories', 'Replacement Wicks']"
#  "['Appliances', 'Parts & Accessories', 'Washer Parts & Accessories']"
#  "['Appliances', 'Laundry Appliances', 'Washers & Dryers', 'Dryers']"
#  "['Appliances', 'Parts & Accessories', 'Humidifier Parts & Accessories', 'Chemicals']"
#  "['Appliances', 'Parts & Accessories', 'Freezer Parts & Accessories']"
#  "['Appliances', 'Parts & Accessories', 'Dishwasher Parts & Accessories']"
#  "['Appliances', 'Parts & Accessories', 'Range Parts & Accessories', 'Knobs']"
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories', 'Handles']"
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Ranges', 'Freestanding Ranges']"
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories', 'Air Filters']"
#  "['Appliances', 'Refrigerators, Freezers & Ice Makers', 'Beverage Refrigerators']"
#  "['Appliances', 'Laundry Appliances', 'Washers & Dryers']"
#  "['Appliances', 'Parts & Accessories', 'Cooktop Parts & Accessories']"
#  "['Appliances', 'Parts & Accessories', 'Washer Parts & Accessories', 'Doors']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Wall Ovens', 'Single Wall Ovens']"
#  "['Appliances', 'Parts & Accessories', 'Dryer Parts & Accessories', 'Lint Screens']"
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories', 'Motors']"
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories', 'Grills']"
#  "['Appliances', 'Parts & Accessories', 'Humidifier Parts & Accessories', 'Humidity Meters']"
#  "['Appliances', 'Parts & Accessories', 'Refrigerator Parts & Accessories', 'Shelves']"
#  "['Appliances', 'Parts & Accessories', 'Fasteners']"
#  "['Appliances', 'Parts & Accessories', 'Range Hood Parts & Accessories', 'Blowers']"
#  "['Appliances', 'Parts & Accessories', 'Range Parts & Accessories', 'Burner Rings']"
#  "['Appliances', 'Dishwashers']"
#  "['Appliances', 'Parts & Accessories', 'Range Parts & Accessories', 'Plug Receptacles']"
#  "['Appliances', 'Parts & Accessories', 'Range Parts & Accessories']"
#  "['Appliances', 'Parts & Accessories', 'Range Parts & Accessories', 'Burners']"
#  "['Appliances', 'Refrigerators, Freezers & Ice Makers', 'Kegerators']"
#  "['Appliances', 'Parts & Accessories', 'Humidifier Parts & Accessories']"
#  "['Appliances', 'Parts & Accessories', 'Dryer Parts & Accessories']"
#  "['Appliances', 'Laundry Appliances', 'Washers & Dryers', 'All-in-One Combination Washers & Dryers']"
#  "['Appliances', 'Parts & Accessories', 'Range Hood Parts & Accessories']"
#  "['Appliances', 'Laundry Appliances', 'Washers & Dryers', 'Washers']"
#  "['Appliances', 'Refrigerators, Freezers & Ice Makers']"
#  "['Appliances', 'Parts & Accessories', 'Oven Parts & Accessories', 'Heating Elements']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Wall Ovens', 'Combination Microwave & Wall Ovens']"
#  "['Appliances', 'Parts & Accessories', 'Oven Parts & Accessories', 'Oven Racks']"
#  "['Appliances', 'Dishwashers', 'Portable Dishwashers']"
#  "['Appliances', 'Ranges, Ovens & Cooktops']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Wall Ovens', 'Double Wall Ovens']"
#  "['Appliances', 'LG Styler Steam Closets']"
#  "['Appliances', 'Parts & Accessories', 'Humidifier Parts & Accessories', 'Accessories']"
#  "['Appliances', 'Parts & Accessories', 'Range Parts & Accessories', 'Exhaust Fans']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Wall Ovens']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Ranges', 'Slide-In Ranges']"
#  "['Appliances', 'Refrigerators, Freezers & Ice Makers', 'Freezers']"
#  "['Appliances', 'Parts & Accessories', 'Beverage Refrigerator Replacement Parts']"
#  "['Appliances', 'Parts & Accessories', 'Air Conditioner Parts & Accessories']"
#  "['Small Appliance Parts & Accessories', 'Coffee & Espresso Machine Parts & Accessories', 'Coffee Machine Accessories', 'Coffee Filters', 'Reusable Filters']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Warming Drawers']"
#  "['Small Appliance Parts & Accessories', 'Coffee & Espresso Machine Parts & Accessories', 'Coffee Machine Accessories', 'Coffee Filters', 'Disposable Filters']"
#  "['Appliances', 'Parts & Accessories', 'Trash Compactor Parts & Accessories']"
#  "['Appliances', 'Ranges, Ovens & Cooktops', 'Ranges']"]
# Total unique 'products' in the reviews dataset: 80

# %%
# main category and detailed categories check

elec_df[['main_category', 'categories']].head(5)
# Out:
#    main_category                                         categories
# 7     Appliances  ['Appliances', 'Parts & Accessories', 'Dryer P...
# 11    Appliances  ['Appliances', 'Laundry Appliances', 'Washers ...
# 37    Appliances  ['Appliances', 'Parts & Accessories', 'Oven Pa...
# 57    Appliances  ['Appliances', 'Refrigerators, Freezers & Ice ...
# 89    Appliances  ['Appliances', 'Laundry Appliances', 'Washers ...

# %%
# convert list to str for categorise values 
import ast 

def list_to_string(categories):
    try:
        if isinstance(categories, str):
            list_obj = ast.literal_eval(categories)
        elif isinstance(categories, list):
            list_obj = categories
        else:
            return str(categories)
        
        return ' '.join(list_obj)
    except Exception as e:
        # Return the original value if pasing fails
        print(f"Error processing value: {categories}. Error: {e}")
        return str(categories)

# %%
elec_df['categories_string'] = elec_df['categories'].apply(list_to_string)
elec_df.head(5)
# Out:
# C:\Users\Hyeon\AppData\Local\Temp\ipykernel_46024\4167320369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elec_df['categories_string'] = elec_df['categories'].apply(list_to_string)
#     product_id main_category  \
# 7   B00AF7WZTM    Appliances
# 11  B09W5PMK5X    Appliances
# 37  B00ECV6EEO    Appliances
# 57  B0C57WMPJQ    Appliances
# 89  B0C2HMPZRB    Appliances
#
#                                            categories  \
# 7   ['Appliances', 'Parts & Accessories', 'Dryer P...
# 11  ['Appliances', 'Laundry Appliances', 'Washers ...
# 37  ['Appliances', 'Parts & Accessories', 'Oven Pa...
# 57  ['Appliances', 'Refrigerators, Freezers & Ice ...
# 89  ['Appliances', 'Laundry Appliances', 'Washers ...
#
#                          user_id  \
# 7   AH6PLOGWYIVIWLJTY756BHNFD4YA
# 11  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 37  AE2TA5GQH4JI5RQ4W5H5PQOVYBGA
# 57  AGJXTLEOLLTIX5AAGFPBZ7CNNVOQ
# 89  AGYEAZK4OEYF2MSSTGJ5WNJDVZKA
#
#                                          product_name  \
# 7   LG 4774EL2001A Genuine OEM Door Hinge for LG D...
# 11  COMFEE’ Washing Machine 2.4 Cu.ft LED Portable...
# 37                 GE WB2X9719 Support Bracket Silver
# 57  Silonn Ice Makers Countertop, 9 Cubes Ready in...
# 89  COSTWAY Compact Laundry Dryer, 110V Electric P...
#
#                                                images  \
# 7   [{'thumb': 'https://m.media-amazon.com/images/...
# 11  [{'thumb': 'https://m.media-amazon.com/images/...
# 37  [{'thumb': 'https://m.media-amazon.com/images/...
# 57  [{'thumb': 'https://m.media-amazon.com/images/...
# 89  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                    datetime  rating  \
# 7   2016-11-28 11:58:20.000     5.0
# 11  2022-04-17 00:01:07.807     5.0
# 37  2020-05-24 20:10:39.354     1.0
# 57  2022-06-10 16:22:20.651     5.0
# 89  2019-09-23 22:44:56.891     5.0
#
#                                              features  \
# 7   ['The LG 4774EL2001A Door Hinge is a genuine O...
# 11  ["AUTO CLEAN - COMFEE' 2.4 Cu.ft portable wash...
# 37  ['The GE Appliances Broil Element Support is a...
# 57  ['Note : Please check the dimension and item w...
# 89  ['【Compact & Portable】The weight of this cloth...
#
#                                           description   price  \
# 7   ['Product Description', "This high quality Gen...   46.27
# 11  ['Feeling unsafe going to Laundromat? Tired of...  399.00
# 37  ['Product Description', 'The high quality GE A...    8.75
# 57  ['Ice in 6 mins - Self Cleaning - Portable - 2...   80.97
# 89                                                 []  259.99
#
#                                     categories_string
# 7   Appliances Parts & Accessories Dryer Parts & A...
# 11  Appliances Laundry Appliances Washers & Dryers...
# 37  Appliances Parts & Accessories Oven Parts & Ac...
# 57  Appliances Refrigerators, Freezers & Ice Maker...
# 89  Appliances Laundry Appliances Washers & Dryers...

# %%
def text_cleaning(text):
    text = str(text).lower()
    # remove special characters
     # Remove any remaining non-alphabetic characters
    text = re.sub(r'[^a-z\s]', '', text)
    return text

# %%
elec_df['sub_categories'] = elec_df['categories_string'].apply(text_cleaning)
# Out:
# C:\Users\Hyeon\AppData\Local\Temp\ipykernel_46024\3663353681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elec_df['sub_categories'] = elec_df['categories_string'].apply(text_cleaning)

# %%
elec_df.head(5)
# Out:
#     product_id main_category  \
# 7   B00AF7WZTM    Appliances
# 11  B09W5PMK5X    Appliances
# 37  B00ECV6EEO    Appliances
# 57  B0C57WMPJQ    Appliances
# 89  B0C2HMPZRB    Appliances
#
#                                            categories  \
# 7   ['Appliances', 'Parts & Accessories', 'Dryer P...
# 11  ['Appliances', 'Laundry Appliances', 'Washers ...
# 37  ['Appliances', 'Parts & Accessories', 'Oven Pa...
# 57  ['Appliances', 'Refrigerators, Freezers & Ice ...
# 89  ['Appliances', 'Laundry Appliances', 'Washers ...
#
#                          user_id  \
# 7   AH6PLOGWYIVIWLJTY756BHNFD4YA
# 11  AHGAOIZVODNHYMNCBV4DECZH42UQ
# 37  AE2TA5GQH4JI5RQ4W5H5PQOVYBGA
# 57  AGJXTLEOLLTIX5AAGFPBZ7CNNVOQ
# 89  AGYEAZK4OEYF2MSSTGJ5WNJDVZKA
#
#                                          product_name  \
# 7   LG 4774EL2001A Genuine OEM Door Hinge for LG D...
# 11  COMFEE’ Washing Machine 2.4 Cu.ft LED Portable...
# 37                 GE WB2X9719 Support Bracket Silver
# 57  Silonn Ice Makers Countertop, 9 Cubes Ready in...
# 89  COSTWAY Compact Laundry Dryer, 110V Electric P...
#
#                                                images  \
# 7   [{'thumb': 'https://m.media-amazon.com/images/...
# 11  [{'thumb': 'https://m.media-amazon.com/images/...
# 37  [{'thumb': 'https://m.media-amazon.com/images/...
# 57  [{'thumb': 'https://m.media-amazon.com/images/...
# 89  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                    datetime  rating  \
# 7   2016-11-28 11:58:20.000     5.0
# 11  2022-04-17 00:01:07.807     5.0
# 37  2020-05-24 20:10:39.354     1.0
# 57  2022-06-10 16:22:20.651     5.0
# 89  2019-09-23 22:44:56.891     5.0
#
#                                              features  \
# 7   ['The LG 4774EL2001A Door Hinge is a genuine O...
# 11  ["AUTO CLEAN - COMFEE' 2.4 Cu.ft portable wash...
# 37  ['The GE Appliances Broil Element Support is a...
# 57  ['Note : Please check the dimension and item w...
# 89  ['【Compact & Portable】The weight of this cloth...
#
#                                           description   price  \
# 7   ['Product Description', "This high quality Gen...   46.27
# 11  ['Feeling unsafe going to Laundromat? Tired of...  399.00
# 37  ['Product Description', 'The high quality GE A...    8.75
# 57  ['Ice in 6 mins - Self Cleaning - Portable - 2...   80.97
# 89                                                 []  259.99
#
#                                     categories_string  \
# 7   Appliances Parts & Accessories Dryer Parts & A...
# 11  Appliances Laundry Appliances Washers & Dryers...
# 37  Appliances Parts & Accessories Oven Parts & Ac...
# 57  Appliances Refrigerators, Freezers & Ice Maker...
# 89  Appliances Laundry Appliances Washers & Dryers...
#
#                                        sub_categories
# 7   appliances parts  accessories dryer parts  acc...
# 11  appliances laundry appliances washers  dryers ...
# 37  appliances parts  accessories oven parts  acce...
# 57  appliances refrigerators freezers  ice makers ...
# 89  appliances laundry appliances washers  dryers ...

# %%
elec_df['sub_categories'].value_counts()
# Out:
# sub_categories
# appliances parts  accessories refrigerator parts  accessories water filters                                                                    73802
# appliances parts  accessories dryer parts  accessories replacement parts                                                                       52783
# appliances refrigerators freezers  ice makers ice makers                                                                                       44098
# appliances laundry appliances washers  dryers portable washers                                                                                 34874
# appliances parts  accessories                                                                                                                  22145
#                                                                                                                                                ...
# appliances ranges ovens  cooktops warming drawers                                                                                                  2
# appliances parts  accessories trash compactor parts  accessories                                                                                   2
# small appliance parts  accessories coffee  espresso machine parts  accessories coffee machine accessories coffee filters disposable filters        2
# appliances ranges ovens  cooktops ranges                                                                                                           2
# small appliance parts  accessories coffee  espresso machine parts  accessories coffee machine accessories coffee filters reusable filters          1
# Name: count, Length: 80, dtype: int64

# %%
elec_df.sub_categories.head(5)
# Out:
# 7     appliances parts  accessories dryer parts  acc...
# 11    appliances laundry appliances washers  dryers ...
# 37    appliances parts  accessories oven parts  acce...
# 57    appliances refrigerators freezers  ice makers ...
# 89    appliances laundry appliances washers  dryers ...
# Name: sub_categories, dtype: object

# %%
# Calculate the average rating for each product 

df_agg = elec_df.groupby('product_name').agg(
    # Calculate the mean rating
    rating = ('rating', 'mean'),
    sub_categories = ('sub_categories', 'first')
).reset_index()

# %%
df_unique = df_agg.copy()

# %%
df_unique = df_unique.reset_index(drop=True)

# %%
print(f"Original product count (with reviews): {len(elec_df)}")
print(f"Unique product count: {len(df_unique)}")
print("DataFrame successfully aggregated to unique products.")
# Out:
# Original product count (with reviews): 408604
# Unique product count: 11378
# DataFrame successfully aggregated to unique products.

# %%
_# vectorization using CountVectorizer

cv_unique = CountVectorizer()
category_features_unique = cv_unique.fit_transform(df_unique['sub_categories'])

# %%
category_features_unique.shape
# Out:
# (11378, 96)

# %%
# 2. Calculate the Cosine Similarity Matrix using the unique features
category_sim_matrix_unique = cosine_similarity(category_features_unique)

# %%
category_sim_matrix_unique.shape
# Out:
# (11378, 11378)

# %%
# function to recommend similar products based on product name 
def recommend_product(
        user_product_input: str, 
        df: pd.DataFrame,
        category_similarity,
        n_recommendations: int = 5,      
        min_rating: float = 4.0,
        similarity_threshold: float = 0.1) -> pd.DataFrame:

    # Find all product name containing the user input 
    matching_products = df[df['product_name'].str.contains(user_product_input, case=False, na=False)]
 
    if matching_products.empty:
      print(f" No Product found matching '{user_product_input}'")
      return pd.DataFrame()

    # product matching    
    seed_product_index = matching_products.index[0]  
    seed_product_name = df.loc[seed_product_index, 'product_name']
    # print(f" Using '{seed_product_name}' as the seed product.")  

   # Get the similarity score for the seed product against all other products 
    category_scores = pd.Series(category_similarity[seed_product_index]) 

   # combine scores with the dataframe and sort 
    sim_df = df.copy()
    sim_df['similarity_score'] = category_scores 

   # filter out the seed product itself 
    sim_df = sim_df[sim_df.index != seed_product_index]

   # Filter by a minimum similarity threshold
    sim_df = sim_df[sim_df['similarity_score'] > similarity_threshold]

   # Filter products below the minimum required rating 
    rated_sim_df = sim_df[sim_df['rating'] >= min_rating] 
  
    if rated_sim_df.empty:
      print(f" No highly rated (>{min_rating}) similar products found. Returning best matches regardless of rating.")
      # If no highly rated products, return the best matches by similarity 
      final_df = sim_df 
    else:
      final_df = rated_sim_df 

   # Final sort by similarity score (descending)
    final_recommendations = final_df.sort_values(by=['similarity_score', 'rating'], ascending=[False, False]).head(n_recommendations)

    return final_recommendations[[ 'product_name', 'sub_categories', 'rating', 'similarity_score' ]]

# %% [markdown]
# ## Testing the function
#
# * To validate that the recommend_product function is working as intended, we will execute it with a sample user query.
# * The function should identify a seed product containing 'washer' in its name, calculate the similarity scores based on its sub-categories, filter by the minimum rating,
#   and return the top recommended products, ranked by similarity.

# %%
# sample query is washer 
user_query = "washer"
min_acceptable_rating = 4.0

recommendations = recommend_product(
    user_product_input=user_query,
    df= df_unique,
    category_similarity = category_sim_matrix_unique,
    min_rating=min_acceptable_rating,
    n_recommendations=5 # Get top 5
)

print("\n--- Recommendations ---")
(recommendations)
# Out:
# --- Recommendations ---
#                                            product_name  \
# 37    (NEW 1oz size) Uber Goop DARK GREY Dishwasher ...
# 460   25 Universal Gray Grey Dishwasher Rack Tip Tin...
# 938   630076 White Vinyl Dishwasher Rack Repair Coat...
# 2403  CoreCentric Remanufactured Dishwasher Control ...
# 2407  CoreCentric Remanufactured Dishwasher Control ...
#
#                                          sub_categories  rating  \
# 37    appliances parts  accessories dishwasher parts...     5.0
# 460   appliances parts  accessories dishwasher parts...     5.0
# 938   appliances parts  accessories dishwasher parts...     5.0
# 2403  appliances parts  accessories dishwasher parts...     5.0
# 2407  appliances parts  accessories dishwasher parts...     5.0
#
#       similarity_score
# 37                 1.0
# 460                1.0
# 938                1.0
# 2403               1.0
# 2407               1.0

# %% [markdown]
# Upon running the function with the query 'washer', the system successfully returned the top 5 most relevant products.
